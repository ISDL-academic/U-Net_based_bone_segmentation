# %%
# !nvidia-smi -L
# Out:
# GPU 0: NVIDIA A100-SXM4-40GB (UUID: GPU-297ac5f8-35c5-3001-e1c7-0263b2130e73)

# %%
# !pip install pydicom
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 28.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# path/to/windowing_jDE

# %%
# %cd /content/drive/MyDrive/個人/M1/研究/windowingProcessing/windowing_jDE
# Out:
# /content/drive/MyDrive/個人/M1/研究/windowingProcessing/windowing_jDE

# %%
# !python main.py
# Out:
# jDE
# 世代数 5 個体数 5
# 1 世代目
# print best individual 0.8156057182236129 [1080.57492632  313.62030444]
# print some individuals 0.8156057182236129 [1080.57492632  313.62030444]
# print some individuals 0.9230199180757601 [1177.48724917  672.89727554]
# print some individuals 0.9434042607839717 [932.92383392 230.54907751]
# 2 世代目
# print best individual 0.8156057182236129 [1080.57492632  313.62030444]
# print some individuals 0.8156057182236129 [1080.57492632  313.62030444]
# print some individuals 0.9230199180757601 [1177.48724917  672.89727554]
# print some individuals 0.9434042607839717 [932.92383392 230.54907751]
# 3 世代目
# print best individual 0.8156057182236129 [1080.57492632  313.62030444]
# print some individuals 0.8156057182236129 [1080.57492632  313.62030444]
# print some individuals 0.9230199180757601 [1177.48724917  672.89727554]
# print some individuals 0.9434042607839717 [932.92383392 230.54907751]
# 4 世代目
# ...
