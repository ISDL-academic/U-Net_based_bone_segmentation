# %% [markdown]
# Confirm GPU

# %%
#!nvidia-smi
# !nvidia-smi -L
# Out:
# GPU 0: NVIDIA A100-SXM4-40GB (UUID: GPU-d06b2b9e-0312-fe78-5858-e1d5a37a16a2)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.12.0

# %% [markdown]
# Run this cell and it will work. Change the path accordingly.
# The result will be stored under "result".
# Parameters like bacth size are written in get_parser.
# _ver2 means this main program run on tensorflow 2.

# %%
import os
os.chdir('/content/drive/My Drive/Unet/')
# !python main_ver2.py
